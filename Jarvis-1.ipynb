# %% [markdown]
# Step 1: Imports and Configuration

# %%
import streamlit as st
import ollama

st.set_page_config(page_title="my app", page_icon=":guardsman:", layout="wide")
st.title("Jarvis")
st.caption("Running on Ollama 3.2 - No data leaves the device")
# Out:
# 2026-04-06 23:24:46.592 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.592 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.670
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/chhavindersingh/.pyenv/versions/3.14.3/lib/python3.14/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-04-06 23:24:46.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# Step 2: Memory

# %%
if "messages" not in st.session_state:
    st.session_state.messages = []
# Out:
# 2026-04-06 23:24:46.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.686 Session state does not function when running a script without `streamlit run`
# 2026-04-06 23:24:46.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Display chat messages from history on app rerun
for msg in st.session_state.messages:
    if msg["role"] == "user":
        st.chat_message(msg["role"]).write(msg["content"])
    else:
        st.chat_message(msg["role"]).write(msg["content"])
# Out:
# 2026-04-06 23:24:46.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Handle user input
if prompt := st.chat_input("What is on your mind?"):
    # 1. Display user message immediately
    st.session_state.messages.append({"role": "user", "content": prompt})
    st.chat_message("user").write(prompt)

    # 2. Placeholder for the AI response
    with st.chat_message("assistant"):
        response_placeholder = st.empty()
        full_response = ""

        # 3. Call the Local Model
        # We use 'stream=True' so the text types out like in ChatGPT
        stream = ollama.chat(
            model='llama3.2',
            messages=[{'role': 'user', 'content': prompt}],
            stream=True,
        )

        # 4. Process the stream
        for chunk in stream:
            if chunk['message']['content']:
                content = chunk['message']['content']
                full_response += content
                response_placeholder.markdown(full_response + "▌")

        # Final update to remove the cursor
        response_placeholder.markdown(full_response)

    # 5. Save the AI's response to history
    st.session_state.messages.append({"role": "assistant", "content": full_response})
# Out:
# 2026-04-06 23:24:46.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 23:24:46.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
